# %%
import pandas as pd

# %%
data  = pd.read_csv('./data_tweet_mood.csv')
data.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1917566086180135193  Wed Apr 30 13:05:56 +0000 2025               0
# 1  1914657152528212025  Tue Apr 22 12:45:58 +0000 2025               0
# 2  1914283269685973394  Mon Apr 21 11:41:11 +0000 2025               0
# 3  1910147964443721889  Thu Apr 10 01:48:58 +0000 2025               0
# 4  1908811645922705496  Sun Apr 06 09:18:55 +0000 2025               0
#
#                                            full_text               id_str  \
# 0  btw emang beneran enak ya kalau kita selalu pu...  1917566086180135193
# 1  @togethur Merasa bersalah karena aku agak setu...  1914661961511346444
# 2  LDM ni bnr2 bisa bkin mood naik turun ya. KIo ...  1914283269685973394
# 3  gak mood bgt KENAPA AKU MERASA JELEK HARI-HARI...  1910147964443721889
# 4  Mood sweet food udah banyak drop. Tapi aku har...  1908811645922705496
#
#   image_url in_reply_to_screen_name lang location  quote_count  reply_count  \
# ...

# %%
clean = data['full_text'].copy()

# %%
clean.head()
# Out:
# 0    btw emang beneran enak ya kalau kita selalu pu...
# 1    @togethur Merasa bersalah karena aku agak setu...
# 2    LDM ni bnr2 bisa bkin mood naik turun ya. KIo ...
# 3    gak mood bgt KENAPA AKU MERASA JELEK HARI-HARI...
# 4    Mood sweet food udah banyak drop. Tapi aku har...
# Name: full_text, dtype: object

# %%
clean.to_csv('mood_data_12.csv', index=False)
